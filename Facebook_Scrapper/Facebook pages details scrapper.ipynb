# %%
from selenium import webdriver
import time
import pandas as pd
from selenium.webdriver.common.keys import Keys
driver = webdriver.Chrome('chromedriver.exe')
driver.get('https://www.facebook.com/BeingSalmanKhan')
driver.find_element_by_name('email').send_keys("amit1.indybytes@gmail}.com")
driver.find_element_by_name('pass').send_keys("amit@1234")
driver.find_element_by_xpath("//input[@value='Log In']").click()

# %%
links2=[]

# %%
while True:
    last_height = driver.execute_script("return document.body.scrollHeight")
    links=driver.find_elements_by_xpath('//a[@class="oajrlxb2 gs1a9yip g5ia77u1 mtkw9kbi tlpljxtp qensuy8j ppp5ayq2 goun2846 ccm00jje s44p3ltw mk2mc5f4 rt8b4zig n8ej3o3l agehan2d sk4xxmp2 rq0escxv nhd2j8a9 a8c37x1j mg4g778l btwxx1t3 pfnyh3mw p7hjln8o kvgmc6g5 cxmmr5t8 oygrvhab hcukyx3x tgvbjcpo hpfvmrgz jb3vyjys rz4wbd8a qt6c0cv9 a8nywdso l9j0dhe7 i1ao9s8h esuyzwwr f1sip0of du4w35lb lzcic4wl abiwlrkh p8dawk7l tm8avpzi"]')
    for i in links:
        try:
            d=i.get_attribute('href')
            print(d)
            if d not in links2:
                links2.append(d)
                
        except:
            pass
    #                 print(l)
    time.sleep(2)
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    time.sleep(6)
    new_height = driver.execute_script("return document.body.scrollHeight")
    if new_height == last_height:
        break
    last_height = new_height
# Out:
# https://www.facebook.com/BeingSalmanKhan/photos/a.334875709933972/3065688310186018/?__cft__[0]=AZVa3ehPiplv_ArLk0y_W5N82hx7Dl7CyvH4nOi8TYyt91PwLMyU_dnphGZDk2V31fjh8zYM-X7KsW7OTVly6GPAt1UDJzvfrekNAhD9QM1w_WT5hGxlnnWvxSoVkn9YIMSs8ZSsPcW6-zuLYRZ1hW7B9-c5x_ONaZQfyye315HYNg&__tn__=EH-R
# https://www.facebook.com/BeingSalmanKhan/photos/a.335663429855200/3057063364381846/?__cft__[0]=AZVc8jjq3bBzZUgwCUdKK6Sd2AZ3tXRSIHtg-QoITpjwTR_B4SO9ZDMCyTv3DbQ_xCwxwEtg7dobp9h_ut2tVPftSmzfRPU3WwCnhyCzFsuCkOXCYJLbabT89yaOTYq2zPKO-LlRrC_D6fHrp5YUYs55v3gTCWq_4MXCv426gvap7w&__tn__=EH-R
# https://www.facebook.com/BeingSalmanKhan/photos/a.334875709933972/3029291967158986/?__cft__[0]=AZVv4Fgfw5A9m8_kcNKoDUBmtAWp9P53WIIgJS_IDWVu1vjbPedNLkyIvE1TlvNL5-EscYZBz1MR_s1A2B1nNPmRiDjBDMKEJAxGBtrOP5a5KiaveZGtvc7ZjHZFsQX65_IqHXMkQ4ynh7F3Vyy_RQzUR39R2-kkLIglqu11SKxQDQ&__tn__=EH-R
# ...

# %%
des1=[]
likes1=[]
comments1=[]
share1=[]
img1=[]

# %%
for i in links2:
    driver.get(i)
    time.sleep(3)
    try:
        des=driver.find_element_by_xpath('//span[@class="oi732d6d ik7dh3pa d2edcug0 qv66sw1b c1et5uql a8c37x1j muag1w35 enqfppq2 jq4qci2q a3bd9o3v knj5qynh oo9gr5id"]').text
        des1.append(des)
    except:
        des1.append('None')
    try:
        likes=driver.find_element_by_xpath('//span[@class="pcp91wgn"]').text
        likes1.append(likes)
    except:
        likes1.append('None')
    try:
        comments=driver.find_element_by_xpath('//span[@class="oi732d6d ik7dh3pa d2edcug0 qv66sw1b c1et5uql a8c37x1j muag1w35 enqfppq2 jq4qci2q a3bd9o3v knj5qynh m9osqain"]').text
        comments1.append(comments)
    except:
        comments1.append('None')
    try:
        share=driver.find_elements_by_xpath('//span[@class="oi732d6d ik7dh3pa d2edcug0 qv66sw1b c1et5uql a8c37x1j muag1w35 enqfppq2 jq4qci2q a3bd9o3v knj5qynh m9osqain"]')
        sha=share[1].text
        share1.append(sha)
    except:
        share1.append('None')
    try:
        img=driver.find_element_by_xpath('//img[@class="nwf6jgls d2edcug0 r0294ipz"]').get_attribute('src')
        img1.append(img)
    except:
        img1.append('None')

# %%
df = pd.DataFrame(
    {'des1': des1,'likes1':likes1,"comments1":comments1,"share1":share1,"img1":img1})
df
# Out:
#                                                  des1 likes1      comments1  \
# 0   جب سے ارطغرل دیکھا ہے، انڈین فلموں کی یکسانیت ...   188K  6.1K Comments
# 1   All d vry best Namashi for #BadBoy. Poster laj...    37K  1.8K Comments
# 2   Sultan Salman Khan came to the world to be one...   109K  3.9K Comments
# 3   I have always respect and love for you.Stay ho...    50K  1.9K Comments
# 4   #Salman, I love your voice. I love your and #J...    83K  2.6K Comments
# ..                                                ...    ...            ...
# 75  Bina mile kabhi pyaar ho sakta hai? Introducin...    37K  1.4K Comments
# 76  ‪Captain.... ‘dubai c u soon....‬\n‪#OrbitEven...    35K  2.1K Comments
# 77  ‪#Bharat wishes every one a happy Republic Day...   121K  4.6K Comments
# 78  Paanch Saal ho Gaye jai ho ko. Thank u bhi bol...    49K  2.5K Comments
# 79  Aao or explore karo fitness ke sab tareeke! Je...    29K  1.3K Comments
#
# ...

# %%
df.to_csv("facebook_data.csv", mode='a',encoding='utf-32',index=False,header=True,sep='\t', escapechar='\\')
